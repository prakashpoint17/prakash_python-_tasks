# %% [markdown]
# 1. Learn Concepts (1 hour)
#     Lists, tuples, sets, dictionaries
#
#     List comprehensions
#
#     String methods
#
#     Exception handling basics

# %%
list1=[10,20,30,14]
print(list1)
# Out:
# [10, 20, 30, 14]
